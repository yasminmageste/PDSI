# %% [markdown]
# <a href="https://colab.research.google.com/github/yasminmageste/PDSI/blob/main/labs/le04_karplus-strong/le04_01_signal_reconstruction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tirando sinais digitais - $x[n]$ ... pra fora do computador - $x(t)$!
#
# 1. Crie um sinal `osc`, com frequência e duração controladas (sinal digital, ou seja, sem $f_s$)
# 2. Crie um sinal ***periódico e aleatório***, com frequência e duração controladas (sem $f_s$)
# 3. Mostre os plots dos sinais em amostras, $x[n]$, e no tempo, $x(t)$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys

# %%
try:
  from google.colab import drive

  drive.mount('/content/drive')
  sys.path.append('/content/drive/MyDrive/UFG/01_teaching/')

except:
  sys.path.append('/home/kuntur/Documents')

# %%
from myAudioProcessingLib import *
from mySignalProcessingLib import *

# %%
def create_sine_signal(M, A=1.0, phi= 0.0, fs=48e3, dur=1.0):
    '''
    M  : period (samples)
    A  : amplitude
    phi: phase
    dur: duration (seconds)
    fs : sampling frequency (Hz)
    '''

    M = int(M)
    w0 = 2 * np.pi / M
    phi = 2 * np.pi / 3
    f = fs / M # frequencia do sinal (Hz)
    N = int(fs * dur)
    n = np.arange(N)

    x = A * np.sin(w0 * n + phi)

    return x, n

# %%
M = 100
fs = 40000
dur = 3
A = 0.5
phi = 0

x, n = create_sine_signal(M, A, phi, fs, dur)

# %%
play(x, fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
N = fs * dur

x2 = SIGNALgenerate(N, 'osc', {'P': 50})

# %%
play(x2, fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
SIGNALplot(x2)

# %%
k = 2

fig, ax = plt.subplots()
ax.stem(np.arange(N), x2, 'r')
ax.set_xlim([0, k * M])
plt.show()

# %% [markdown]
# ## Desafio
#
# A partir da primitiva `SIGNALgenerate`, crie a função `SIGNALtone`, que permita criar um ***tom*** com ***3 segundos de duração*** e uma ***frequencia audível*** de $$\Large f=330\,(Hz)!$$

# %%
def SIGNALtone(f=440, dur=1.0):
    '''
    Tone with a predefined frequecy and duration

    f: Signal frequency
    dur: Duration (seconds)

    x: Output signal
    fs: Sampling freq. (default: CD standard)
    '''

    x, _ = SIGNALgenerate(...)

    return x, fs

# %%
f = 330 # signal freq (Hz)
dur = 3.0 # duration (s)

# %%
x, fs = SIGNALtone(f, dur)

# %%
play(x, fs)

# %% [markdown]
# Como poderiamos comprovar que "deu certo"?

# %%
n = np.arange(x.shape[0])
N = n.shape[0]

X = ...
fHz = ...

# %%
Xmag = ...

# %%
fig, ax = plt.subplots()
ax.plot(fHz, Xmag, 'm')
ax.set_xlim([ 0, .02 * (fs / 2)])
figureFormat(ax, fig)
plt.show()

# %% [markdown]
# ## Desafio - `osc2`
#
# A partir da primitiva `SIGNALgenerate`, crie a função `SIGNALwaveform`, que admita tons com ***formas de onda*** (*waveforms*) distintas

# %%
def SIGNALwaveform(f=440, dur=1.0):
    '''
    Tone with a random waveform as input

    f: Signal frequency
    dur: Duration (seconds)

    x: Output signal
    fs: Sampling freq. (default: CD standard)
    '''



    return x, fs

# %%
f = 330
dur = 2

y, fs = SIGNALwaveform(f, dur)

# %%
play(y, fs)

# %%
Y = ...
fHz_y = ...

Ymag = ...

fig, ax = plt.subplots()
ax.plot(fHz_y, Ymag, 'm')
ax.set_xlim([ 0, .02 * (fs / 2) ])
figureFormat(ax, fig)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(ny, y, 'm')
ax.set_xlim([ 0, 10 * (fs / f) ])
figureFormat(ax, fig)
plt.show()
